# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\haydencordeiro\AppData\Local\Temp\ipykernel_22092\3822599577.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Data Loading

# %%
df = pd.read_excel('./data/population_ghi_unemploment_yearwise_import export_africa_sheet.xlsx')
df
# Out:
#     Year  Population        GHI  Unemployment Above age 15  \
# 0   1960   277118493  58.600464                   9.481062
# 1   1961   283779876  58.262490                   9.570610
# 2   1962   290712155  57.919486                   9.414767
# 3   1963   297898741  57.558272                   9.451991
# 4   1964   305365652  56.318315                   9.389307
# ..   ...         ...        ...                        ...
# 58  2018  1252369090  25.211270                   9.061706
# 59  2019  1283595475  25.236349                   9.147912
# 60  2020  1315356983  25.261429                   9.895824
# 61  2021  1347125535  25.321429                  10.147794
# 62  2022  1378946751  25.401429                   9.476603
#
#     Unemployment between age 15-24  Unemployment Above age 25+  \
# 0                        15.990643                    5.855937
# 1                        16.011023                    6.001037
# 2                        15.847811                    5.871723
# ...

# %% [markdown]
# # Handle Missing Data if Any

# %%
# Visualizations (you can add more visualizations based on your specific analysis needs)
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of GHI (Global Hunger Index)
plt.figure(figsize=(8, 6))
sns.histplot(df['GHI'], bins=20, kde=True, color='blue')
plt.title('Distribution of Global Hunger Index (GHI)')
plt.xlabel('GHI')
plt.ylabel('Frequency')
plt.show()

# %%
cols  = (df.columns.values)
firstset = cols[0:7]
secondset = cols[7:]
np.append(secondset, 'GHI')
sns.pairplot(df[firstset])
plt.show()

sns.pairplot(df[secondset])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram and Density Plot for a numerical variable
plt.figure(figsize=(8, 6))
sns.histplot(df['GHI'], bins=20, kde=True, color='blue')
plt.title('Histogram and Density Plot of Global Hunger Index (GHI)')
plt.xlabel('GHI')
plt.ylabel('Density')
plt.show()

# %%
# Box Plot for a numerical variable
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Unemployment Above age 15'])
plt.title('Box Plot of Unemployment Above age 15')
plt.xlabel('Unemployment Above age 15')
plt.show()

# %%
# Violin Plot for a numerical variable
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['Unemployment Above age 15'])
plt.title('Violin Plot of Unemployment Above age 15')
plt.xlabel('Unemployment Above age 15')
plt.show()

# %%
# Scatter Plot with Regression Line
plt.figure(figsize=(8, 6))
sns.regplot(x='Import (US$ Thousand)', y='Export (US$ Thousand)', data=df)
plt.title('Scatter Plot with Regression Line')
plt.xlabel('Import (US$ Thousand)')
plt.ylabel('Export (US$ Thousand)')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Bar Plot for a categorical variable
plt.figure(figsize=(8, 6))
sns.countplot(x=df['Year'] // 10 * 10)  # Grouping years by decade
plt.title('Count of Observations by Decade')
plt.xlabel('Decade')
plt.ylabel('Count')
plt.show()
